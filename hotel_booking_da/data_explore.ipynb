# %% [markdown]
# # hotel booking data exploring

# %% [markdown]
# data loding and understanding

# %% [markdown]
# import librarys

# %%
#import librarys
import pandas as pd 
import numpy as np 
import  matplotlib.pyplot as plt 
import seaborn as sns

# %%
# loading and working with pathlib module 
from pathlib import Path 
path=Path('./hotel_bookings.csv')
hotel_data=pd.read_csv(path)

# %%
# data loading 
#copy of org data 
df=hotel_data.copy()

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.sample(5)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 104307    City Hotel            0          1               2017
# 72720     City Hotel            1        128               2017
# 8285    Resort Hotel            0        397               2016
# 94598     City Hotel            0        152               2016
# 34425   Resort Hotel            0         47               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 104307            January                         2
# 72720              August                        31
# 8285            September                        39
# 94598              August                        32
# 34425               March                        12
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 104307                         10                        0
# 72720                           4                        0
# 8285                           21                        0
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
#data types
df.info(max_cols=32)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=119390, step=1)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# checking missing vlaue 
first_16 =df.iloc[:,:16]

# %%
first_16.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel'],
#       dtype='object')

# %%
second_halg=df.iloc[:,16:]
second_halg.columns
# Out:
# Index(['is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# i want to see missing columns
print("first half\n")
first_16.isnull().sum()
# Out:
# first half
# hotel                          0
# is_canceled                    0
# lead_time                      0
# arrival_date_year              0
# arrival_date_month             0
# arrival_date_week_number       0
# arrival_date_day_of_month      0
# stays_in_weekend_nights        0
# stays_in_week_nights           0
# adults                         0
# children                       4
# babies                         0
# meal                           0
# country                      488
# market_segment                 0
# distribution_channel           0
# dtype: int64

# %%
#second half columns 
second_halg.isnull().sum()
# Out:
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# dtype: int64

# %% [markdown]
# ## copying them inot df1 and df2

# %%
df1=first_16
df2=second_halg

# %%
df1.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# to look mathmetically info columns
print('first half describe')
df1.describe()
# Out:
# first half describe
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# second half 
print('second half describe()')
df2.describe()
# Out:
# second half describe()
#        is_repeated_guest  previous_cancellations  \
# count      119390.000000           119390.000000
# mean            0.031912                0.087118
# std             0.175767                0.844336
# min             0.000000                0.000000
# 25%             0.000000                0.000000
# 50%             0.000000                0.000000
# 75%             0.000000                0.000000
# max             1.000000               26.000000
#
#        previous_bookings_not_canceled  booking_changes          agent  \
# count                   119390.000000    119390.000000  103050.000000
# mean                         0.137097         0.221124      86.693382
# std                          1.497437         0.652306     110.774548
# min                          0.000000         0.000000       1.000000
# 25%                          0.000000         0.000000       9.000000
# 50%                          0.000000         0.000000      14.000000
# ...

# %%
# to find duplicats
print("duplicates in first half:")
df1.duplicated().sum()
# Out:
# duplicates in first half:
# np.int64(38688)

# %%
# to find duplicats
print("duplicates in second half:")
df2.duplicated().sum()
# Out:
# duplicates in second half:
# np.int64(38076)

# %%
df1.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
# identify correlation
df1.corr(numeric_only=True)
# Out:
#                            is_canceled  lead_time  arrival_date_year  \
# is_canceled                   1.000000   0.293123           0.016660
# lead_time                     0.293123   1.000000           0.040142
# arrival_date_year             0.016660   0.040142           1.000000
# arrival_date_week_number      0.008148   0.126871          -0.540561
# arrival_date_day_of_month    -0.006130   0.002268          -0.000221
# stays_in_weekend_nights      -0.001791   0.085671           0.021497
# stays_in_week_nights          0.024765   0.165799           0.030883
# adults                        0.060017   0.119519           0.029635
# children                      0.005048  -0.037622           0.054624
# babies                       -0.032491  -0.020915          -0.013192
#
#                            arrival_date_week_number  \
# is_canceled                                0.008148
# lead_time                                  0.126871
# ...

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# ...

# %%
missing=df.isnull().sum().sort_values(ascending=False)/len(df)
missing[missing!=0].plot(kind='barh')
# Out:
# <Axes: >

# %%
df['company'].isnull().sum()
# Out:
# np.int64(112593)

# %% [markdown]
# ** company column is missing more than half of the total values better to drop **

# %%
df.drop(labels='company',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df['children']=df['children'].fillna(df['children'].mean())

# %%
df['agent']=df['agent'].fillna(df['agent'].mean())
df['agent'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['country']=df['country'].fillna(df['country'].mode()[0])

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
# finding duplicates 
dup_per=(df.duplicated().sum()/len(df))*100
dup_per
# Out:
# np.float64(26.819666638746963)

# %%
df.sample(5)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 44987    City Hotel            1        102               2015
# 89044    City Hotel            0         93               2016
# 87301    City Hotel            0          1               2016
# 2382   Resort Hotel            1        143               2015
# 91538    City Hotel            0          0               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 44987            October                        42                         16
# 89044                May                        20                         12
# 87301              April                        16                         16
# 2382             October                        41                         10
# 91538               June                        26                         21
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
df.to_csv('processed_data')
